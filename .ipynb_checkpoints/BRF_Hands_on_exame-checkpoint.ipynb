# %% [markdown]
# ## Question 8

# %%
def stepsToTheRight (num,x):
    x= x % len(num)
    return num[-x:] + num[:-x]

num = [1,2,3,4,5,6,7,8,9]
print(stepsToTheRight(num,11))
# Out:
# [8, 9, 1, 2, 3, 4, 5, 6, 7]
